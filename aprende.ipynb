# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciomontenegro/amigo-secreto/blob/main/aprende.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre_usuario = input("¿Cómo te llamas? ")
print("Hola, " + nombre_usuario + ". ¡Bienvenido al sistema!")
# Out:
# ¿Cómo te llamas? patricio Montenegro
# Hola, patricio Montenegro. ¡Bienvenido al sistema!

# %%
cantidad_agua = input("¿cuantos ml de agua necesitas? ")
print("servidos tus " + cantidad_agua+ ". ¡disfrutala!")
# Out:
# ¿cuantos ml de agua necesitas? 200
# servidos tus 200. ¡disfrutala!

# %%
# Convertimos la entrada de texto a un número entero
cantidad_agua = int(input("¿Cuántos ml de agua necesitas? "))

# Ahora podemos hacer cálculos
capacidad_tanque = 1000
nuevo_total = capacidad_tanque - cantidad_agua
# Out:
# ¿Cuántos ml de agua necesitas? 200

# %%
capacidad_tanque = 1000
cantidad_agua = int(input("¿Cuántos ml necesitas? "))

if cantidad_agua >= capacidad_tanque:
    print("No hay suficiente agua en el tanque.")
else:
    print("Sirviendo agua...")
# Out:
# ¿Cuántos ml necesitas? 1200
# No hay suficiente agua en el tanque.

# %%
tanque_vacio = True

if tanque_vacio:
    print("Por favor, rellene el tanque.")
# Out:
# Por favor, rellene el tanque.

# %%
usuarios = ["ana", "luis", "marta"]

# %%
usuarios.append("Pedro")

# %%
print (usuarios)
# Out:
# ['ana', 'luis', 'marta', 'Pedro']

# %%
usuarios = ["Ana", "Luis", "Marta", "Pedro"]

for nombre in usuarios:
    print("Hola " + nombre + ", tu agua está lista.")
# Out:
# Hola Ana, tu agua está lista.
# Hola Luis, tu agua está lista.
# Hola Marta, tu agua está lista.
# Hola Pedro, tu agua está lista.

# %%
tanque = 100

while tanque > 0:
    print("Sirviendo 20ml... Quedan " + str(tanque) + "ml")
    tanque = tanque - 20

print("Tanque vacío.")
# Out:
# Sirviendo 20ml... Quedan 100ml
# Sirviendo 20ml... Quedan 80ml
# Sirviendo 20ml... Quedan 60ml
# Sirviendo 20ml... Quedan 40ml
# Sirviendo 20ml... Quedan 20ml
# Tanque vacío.

# %%
def dispensar_agua(cantidad):
    if cantidad <= 100:
        print("Sirviendo " + str(cantidad) + "ml...")
    else:
        print("Error: Cantidad demasiado grande.")

# %%
# 1. Entrada de datos
nombre = input("¿Cuál es tu nombre? ")

# 2. Procesamiento (Guardar en la lista)
clientes = []
clientes.append(nombre)

# 3. Salida de datos (Confirmación)
print("Cliente " + nombre + " registrado con éxito.")
# Out:
# ¿Cuál es tu nombre? lelo
# Cliente lelo registrado con éxito.
